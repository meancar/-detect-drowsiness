# %%
from keras_facenet import FaceNet

# %%
model = FaceNet().model

# %%
model.summary()
# Out:
# Model: "inception_resnet_v1"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ...
#  input_1 (InputLayer)        [(None, None, None, 3)]      0         []
#
#  Conv2d_1a_3x3 (Conv2D)      (None, None, None, 32)       864       ['input_1[0][0]']
#
#  Conv2d_1a_3x3_BatchNorm (B  (None, None, None, 32)       96        ['Conv2d_1a_3x3[0][0]']
#  atchNormalization)
#
#  Conv2d_1a_3x3_Activation (  (None, None, None, 32)       0         ['Conv2d_1a_3x3_BatchNorm[0][0
#  Activation)                                                        ]']
#
#  Conv2d_2a_3x3 (Conv2D)      (None, None, None, 32)       9216      ['Conv2d_1a_3x3_Activation[0][
#                                                                     0]']
#
#  Conv2d_2a_3x3_BatchNorm (B  (None, None, None, 32)       96        ['Conv2d_2a_3x3[0][0]']
#  atchNormalization)
#
# ...
